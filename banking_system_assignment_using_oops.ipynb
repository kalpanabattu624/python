# %% [markdown]
# ## ASSIGNMENT: Banking System using OOPS in Python
#
# Step 1: Create a base class Account
# The Account class should:
# •	Have a private variable __balance
# •	Initialize balance using constructor
# •	Provide methods:
# o	deposit(amount) → add amount to balance
# o	get_balance() → return current balance
# The balance should not be directly accessible outside the class.
# ________________________________________
# Step 2: Create a child class Savings_Account
# The Savings_Account class should:
# •	Inherit from Account
# •	Have a method display_balance() that prints the balance using the parent method
# ________________________________________
# Step 3: Object Creation
# •	Create an object of Savings_Account
# •	Deposit some amount
# •	Display the balance
# ________________________________________
# Step 4: Understanding Internals
# •	Print the object’s __dict__
# •	Observe how Python stores private variables internally

# %%
class account:
    def __init__(self,balance):
        self.__balance =balance
    def deposit(self,amount):
        self.__balance+=amount
    def getbalance(self):
        return (self.__balance, "is this current balance")

class savings_account(account):
    def displaybalance(self):
        print(self.getbalance())


c1 = savings_account(1000)
c1.deposit(500)
# c1.getbalance()
c1.displaybalance()
        
c1.__dict__



# Change this:
#print(my_account.get_balance)

# To this:
#print(my_account.get_balance())
# Out:
# (1500, 'is this current balance')
# {'_account__balance': 1500}

# %% [markdown]
# ## Mini E-Commerce System using Python OOP
#
# Context:
# You are hired as a junior software developer to work on a mini e-commerce system for a startup. Your task is to design a simplified system using Python's Object-Oriented Programming (OOP) principles. This project will involve building a basic structure of an e-commerce application that handles products, applies discounts based on product categories, and demonstrates secure access to product data.
#
# Objectives:
# 1.	Understand and implement inheritance by creating a hierarchy of product categories.
# 2.	Demonstrate polymorphism by applying different discount rates for different product types.
# 3.	Apply encapsulation to protect and manage product data securely.
#
# Requirements:
# You need to develop a Python program with the following features:
#
# 1. Product Class (Base Clh[]10+
#     ass)
# Create a base class named Product with the following characteristics:
#
# •	Attributes (Private):
#
# o	product_id (integer): A unique identifier for each product.
# o	name (string): The name of the product.
# o	price (float): The original price of the product.
#
# •	Methods:
#
# o	Constructor (__init__): Initialize the product attributes with provided values.
# o	Getter Methods: get_product_id(), get_name(), get_price() to retrieve the values of the attributes.
# o	Setter Method: set_price(price) to update the price of the product.
# o	apply_discount(): A method that returns the price without any discount (default behavior).
#
# 2. Inheritance - Subclasses for Product Categories
# You need to extend the Product class to create specialized product categories:
# •	Electronics (Subclass):
# o	Additional Attribute:
# 	warranty_period (integer): The warranty period in years.
# o	Override the apply_discount() method to provide a 10% discount for electronics products.
# •	Clothing (Subclass):
# o	Additional Attribute:
# 	material (string): The material of the clothing (e.g., "Cotton", "Wool").
# o	Override the apply_discount() method to provide a 20% discount for clothing products.
#
#
# 3. Encapsulation - Secure Access to Product Data
# Ensure that the product details (product_id, name, price) are private and cannot be accessed directly. Use getter and setter methods to access or modify the data.
#
#
# 4. Additional Features
# Implement the following features:
# •	Add a method to update the price of a product using the setter method.
# •	Implement an __str__() method for the Product class to provide a formatted string representation of the product details.
#
#
# 5. Test the System
# •	Create a few products of each type (Electronics and Clothing).
# •	Print the details of each product, including the discounted price.
# •	Demonstrate the usage of inheritance and encapsulation.

# %%
class product:
    def __init__(self,product_id:int,name:str,price:float):
        self.__product_id = product_id
        self.__name = name
        self.__price = price
    def get_product_id(self):
        return (self.__product_id)
    def get_name(self):
        return (self.__name)
    def get_price(self):
        return (self.__price)
    def set_price(self,new_price):
        return (self.__price == new_price)
    def apply_discount(self): 
        return (self.__price)

class electronics(product):
    def __init__(self,product_id,name,price,warranty_period:int ):
       
        super().__init__(product_id,name,price)
        self.warranty_period=warranty_period

        def apply_discount(self): 
            return self.get_price()* 0.1 
        
        

class clothing(product):
    def __init__(self,product_id,name,price,material:str):

        super().__init__(product_id,name,price)
        self.material=material

        
        def apply_discount(self): 
            return self.get_price ()* 0.2



product = electronics (11,'laptop', 50000.0,7)   


print(product.get_product_id())
print(product.get_name())
print(product.get_price())
# print(product.__set_price())
print(product.apply_discount())


product = clothing(12,'saree', 15000.0,'silk saree')   


print(product.get_product_id())
print(product.get_name())
print(product.get_price())
# print(product.__set_price())
print(product.apply_discount())
# Out:
# 11
# laptop
# 50000.0
# 50000.0
# 12
# saree
# 15000.0
# 15000.0

# %%
  def set_price(self, new_price):
        if new_price > 0:
            self._price = new_price
            print(f"Price updated to {new_price}")
        else:
            print("Error: Price must be positive.")

# %%
class product:
    def __init__(self,product_id:int,name:str,price:float):
        self.__product_id = product_id
        self.__name = name
        self.__price = price
    def get_product_id(self):
        return (self.__product_id)
    def get_name(self):
        return (self.__name)
    def get_price(self):
        return (self.__price)
    def set_price(self, new_price):
        if new_price > 0:
            self._price = new_price
            print(f"Price updated to {new_price}")
        else:
            print("Error: Price must be positive.")
   # def set_price(self,new_price):
        #return (self.__price == new_price)



        
    def apply_discount(self): 
        return (self.__price)

class electronics(product):
    def __init__(self,product_id,name,price,warranty_period:int ):
       
        super().__init__(product_id,name,price)
        self.warranty_period=warranty_period

        def apply_discount(self): 
            return self.get_price()* 0.1 
        
        

class clothing(product):
    def __init__(self,product_id,name,price,material:str):

        super().__init__(product_id,name,price)
        self.material=material

        
        def apply_discount(self): 
            return self.get_price ()* 0.2



product = electronics (11,'laptop', 50000.0,7)   


print(product.get_product_id())
print(product.get_name())
print(product.get_price())
# print(product.__set_price())
print(product.apply_discount())


product = clothing(12,'saree', 15000.0,'silk saree')   


print(product.get_product_id())
print(product.get_name())
print(product.get_price())
#print(product.__set_price())
print(product.apply_discount())
# Out:
# 11
# laptop
# 50000.0
# 50000.0
# 12
# saree
# 15000.0
# 15000.0
